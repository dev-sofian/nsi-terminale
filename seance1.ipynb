# %% [markdown]
# # Séance 1 — Diagnostic : variables, types, structures de contrôle

# %% [markdown]
# ### Compétences du programme visées
# - [Langages et programmation] « Mettre en évidence un corpus de constructions élémentaires » (séquences, affectation, conditionnelles, boucles bornées, boucles non bornées, appels de fonction)
# - [Algorithmique] « Écrire un algorithme de recherche d'un extremum, de calcul d'une moyenne »
#
#
# ### Objectifs pédagogiques
# 1. L'élève sera capable d'identifier une erreur de syntaxe ou de logique dans un court programme Python (affectation, typage, conditionnelle).
# 2. L'élève sera capable d'écrire une boucle bornée (`for`) et une boucle non bornée (`while`) adaptées à un énoncé simple.
# 3. L'élève sera capable de tracer à la main l'exécution d'un programme court pour prédire sa sortie avant de l'exécuter.

# %% [markdown]
# ### 📚 Explication 1 — Variables, types et le piège du `=` / `==`
#
# **🎯 Objectif de ce bloc** : identifier une erreur de syntaxe ou de logique liée aux variables, types et conditions.
#
# **🟢 Guidé**
# ```python
# age = 17          # affectation : on range 17 dans la boîte "age"
# if age == 17:      # test d'égalité : on compare age à 17
#     print("Tu as 17 ans")
# ```
# Vérification : que se passe-t-il si on écrit `if age = 17:` au lieu de `if age == 17:` ? (essaie, Python va te renvoyer une erreur — lis le message.)
#
# **🟡 Intermédiaire** — `=` affecte une valeur, `==` compare deux valeurs. Une erreur de typage classique : `"17" == 17` renvoie `False` (chaîne vs entier).
# **Point de vigilance** : `input()` renvoie toujours une chaîne de caractères, même si l'utilisateur tape un nombre — il faut la convertir avec `int()` ou `float()`.
#
# **🔴 Expert** — Question ouverte : pourquoi `0.1 + 0.2 == 0.3` renvoie-t-il `False` en Python ? Teste-le.

# %% [markdown]
# #### ✏️ Activité 1
#
# **🟢 Guidé**
# ```python
# age = int(input("Quel âge as-tu ? "))
# if age ____ 18:      # complète avec le bon symbole de comparaison
#     print("majeur")
# else:
#     print("mineur")
# ```
# *Consigne : complète le symbole de comparaison manquant, puis teste avec 15 et avec 20.*
#
# **🟡 Intermédiaire**
# ```python
# note = float(input("Quelle est ta note sur 20 ? "))
# if note >= 16:
#     print("très bien")
# elif note >= 14:
#     print("bien")
# elif note >= 12:
#     print("assez bien")
# # il manque un cas !
# ```
# *Consigne : ce code ne gère pas les notes en dessous de 12. Complète-le avec un `else` qui affiche "passable", puis teste avec 10, 13, 17.*
#
# **🔴 Expert**
# ```python
# a = 0.1 + 0.2
# print(a == 0.3)        # affiche False !
# print(abs(a - 0.3) < 1e-9)   # affiche True
# ```
# *Consigne : exécute ce code, puis explique en une phrase pourquoi la seconde ligne est une meilleure façon de comparer deux flottants.*
#
# ---

# %% [markdown]
# ### 📚 Explication 2 — Boucles `for` et `while`
#
# **🎯 Objectif de ce bloc** : écrire une boucle bornée (`for`) et une boucle non bornée (`while`) adaptées à un énoncé.
#
# **🟢 Guidé**
# ```python
# for i in range(1, 6):
#     print(i)          # affiche 1 2 3 4 5
#
# compteur = 0
# while compteur < 3:
#     print(compteur)
#     compteur = compteur + 1   # sans cette ligne, boucle infinie !
# ```
# Vérification : que se passe-t-il si on supprime la ligne `compteur = compteur + 1` ?
#
# **🟡 Intermédiaire** — `for` quand on connaît à l'avance le nombre de répétitions, `while` quand on répète "tant qu'une condition est vraie" (nombre de tours inconnu).
# **Point de vigilance** : une boucle `while` doit toujours faire évoluer la variable testée dans sa condition.
#
# **🔴 Expert** — Question ouverte : peux-tu réécrire une boucle `for i in range(5)` en `while` strictement équivalente ?

# %% [markdown]
# #### ✏️ Activité 2
#
# **🟢 Guidé**
# ```python
# for i in range(1, ____):   # complète pour afficher 1 à 5
#     print(i)
# ```
# *Consigne : complète le pointillé, vérifie que l'affichage va bien de 1 à 5.*
#
# **🟡 Intermédiaire**
# ```python
# n = int(input("Compte à rebours depuis : "))
# while n ____ 0:      # complète la condition
#     print(n)
#     n = n - 1
# print("Décollage !")
# ```
# *Consigne : complète la condition manquante, teste avec `n = 5`.*
#
# **🔴 Expert**
# ```python
# def for_en_while(n):
#     # réécris range(n) avec une boucle while, doit afficher les mêmes valeurs
#     pass
#
# def for_classique(n):
#     for i in range(n):
#         print(i)
# ```
# *Consigne : écris `for_en_while(5)` pour qu'elle affiche exactement la même chose que `for_classique(5)`, en utilisant `while`.*
#
# ---

# %% [markdown]
# ### 📚 Explication 3 — Tracer l'exécution d'un programme
#
# **🎯 Objectif de ce bloc** : prédire la sortie d'un programme court avant de l'exécuter.
#
# **🟢 Guidé**
# ```python
# total = 0
# for x in [3, 5, 2]:
#     total = total + x
# print(total)
# ```
# Vérification : sans exécuter, que vaut `total` à la fin ? Vérifie ensuite en exécutant.
#
# **🟡 Intermédiaire** — Tracer un programme, c'est noter la valeur de chaque variable après chaque ligne exécutée, comme un tableau.
# **Point de vigilance** : bien distinguer la valeur *avant* et *après* chaque instruction.
#
# **🔴 Expert** — Question ouverte : dans une boucle `while`, comment prouverais-tu qu'elle se termine forcément (variant de boucle) ?

# %% [markdown]
# #### ✏️ Activité 3
#
# **🟢 Guidé**
# ```python
# x = 2
# y = 5
# x = y
# y = x
# print(x, y)
# ```
# *Consigne : prédis l'affichage sur papier avant d'exécuter. Beaucoup se trompent — pourquoi ?*
#
# **🟡 Intermédiaire**
# ```python
# notes = [12, 8, 15]
# total = 0
# for n in notes:
#     total = total + n
# moyenne = total / len(notes)
# print(moyenne)
# ```
# *Consigne : trace ligne par ligne la valeur de `total`, puis calcule `moyenne` à la main avant d'exécuter.*
#
# **🔴 Expert**
# ```python
# def factorielle(n):
#     if n == 0:
#         return 1
#     return n * factorielle(n - 1)
#
# print(factorielle(4))
# ```
# *Consigne : trace à la main les appels successifs de `factorielle(4)` jusqu'à `factorielle(0)`, puis explique pourquoi cette fonction termine forcément.*
#
# ### ✅ Bilan de la notion
# - `=` affecte une valeur, `==` compare deux valeurs — ne pas confondre.
# - `for` pour un nombre de répétitions connu, `while` pour "tant que", en veillant à faire évoluer la condition.
#
# - Tracer un programme à la main (noter chaque variable après chaque ligne) permet de prédire sa sortie avant de l'exécuter.
#
# ---

# %% [markdown]
# ## 📗 TD
#
# ### Rappel express
# - `=` affecte, `==` compare.
# - `for` = nombre de répétitions connu ; `while` = répéter tant qu'une condition est vraie.
# - Tracer un programme = suivre la valeur de chaque variable ligne par ligne.
#
# ### 🟢 Partie guidée
# ```python
# for i in range(1, 11):
#     if i % 2 ____ 0:
#         print(i)
# ```
# *Consigne : complète pour afficher les nombres pairs de 1 à 10.*
#
# ### 🟡 Partie intermédiaire
# Écris un programme qui demande des notes une par une (boucle `while`) jusqu'à ce que l'utilisateur tape `-1`, puis affiche la moyenne des notes saisies (hors `-1`).
#
# ### 🔴 Partie experte
# Écris un petit jeu "plus ou moins" : le programme choisit un nombre entre 1 et 100 (`random.randint(1, 100)`), l'utilisateur propose des nombres, le programme répond "plus grand" ou "plus petit" jusqu'à ce qu'il trouve. Compte et affiche le nombre d'essais.
#
# ---

# %% [markdown]
# ## ✏️ Exercices différenciés finaux
#
# ### 🟢 Exercices Guidés
# 1. Corrige le bug : `if age = 18:` doit devenir `if age == 18:`.
# 2. Complète une boucle `for` affichant 1 à 5.
# 3. QCM : parmi ces 3 lignes, laquelle contient une erreur de syntaxe ?
# ```python
# # a) if x = 5: Celle là.
# # b) if x == 5:
# # c) while x < 5:
# ```
#
# ### 🟡 Exercices Intermédiaires
# 1. Programme note → mention avec gestion de tous les cas (y compris `< 12`).
# 2. Compte à rebours en `while` à partir d'un nombre saisi.
# 3. Calcule la moyenne d'une liste de notes `[12, 8, 15, 10]`.
#
# ### 🔴 Exercices Experts
# 1. Affiche tous les nombres premiers jusqu'à un N donné.
# 2. Écris `factorielle(n)` récursive et explique en commentaire pourquoi elle termine forcément.
# 3. Jeu "plus ou moins" complet, avec justification du choix `for`/`while` pour la boucle principale.
#  - Si l'on prend une boucle `for`, c'est sûrement lorsque le jeu implante un nombre de tentatives limité. Pour la boucle `while`, c'est sûrement que le joueur a un nombre indéfini de tentatives et avec la condition de "gagner" pour fermer la boucle.
#
# ### 🟣 Défi (pour les élèves en avance)
# Écris deux fonctions `for_en_while` et `while_en_for` qui transforment une boucle de l'un en l'autre pour n'importe quelle liste donnée, et explique dans quel cas cette transformation est impossible.
#
# ### ✅ Critères de réussite
# - 🟢 Je suis capable d'identifier une erreur de syntaxe simple et de compléter une boucle `for`.
# - 🟡 Je maîtrise l'écriture d'un programme avec conditions imbriquées et une boucle `while` qui termine.
# - 🔴 Je suis capable d'écrire une fonction récursive simple et d'en expliquer la terminaison.
# - 🟣 Je suis capable de transformer une structure de boucle en une autre et d'en identifier les limites.
