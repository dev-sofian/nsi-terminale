# %% [markdown]
# # Séance 2 — Écrire un algorithme avant de coder : du pseudo-code au Python
#
#
# ### Compétences du programme visées
# - [Préambule] « décomposer un problème en sous-problèmes, reconnaître des situations déjà analysées et réutiliser des solutions »
# - [Préambule] « concevoir des solutions algorithmiques »
# - [Préambule] « traduire un algorithme dans un langage de programmation, en spécifier les interfaces et les interactions (...) »
# - [Langages et programmation — Spécification] « Prototyper une fonction. Décrire les préconditions sur les arguments. Décrire des postconditions sur les résultats. »
#
#
#
# ### Objectifs pédagogiques
# 1. L'élève sera capable de décomposer un énoncé de problème en étapes numérotées avant d'écrire du code.
# 2. L'élève sera capable de rédiger un algorithme en pseudo-code indépendamment de la syntaxe Python.
# 3. L'élève sera capable de traduire un pseudo-code en programme Python fonctionnel.
# 4. L'élève sera capable de comparer deux algorithmes résolvant le même problème et de justifier une préférence.

# %% [markdown]
# ### 📚 Explication 1 — Décomposer un problème en pseudo-code
#
# **🎯 Objectif de ce bloc** : décomposer un énoncé en étapes numérotées, indépendamment de la syntaxe.
#
# **Problème :** trouver le plus grand nombre d'une liste
#
#
# **🟢 Guidé**
# ```
# Problème : trouver le plus grand nombre d'une liste
# 1. Je garde en mémoire le premier nombre comme "le plus grand pour l'instant"
# 2. Je regarde chaque nombre suivant un par un
# 3. Si ce nombre est plus grand, je le remplace
# 4. À la fin, "le plus grand pour l'instant" est la réponse
# ```
# Vérification : sur la liste `[3, 9, 2]`, déroule les 4 étapes à la main.
#
# **🟡 Intermédiaire** — Le pseudo-code vérifie la logique avant de se soucier de la syntaxe Python.
# **Point de vigilance** : un pseudo-code qui "oublie" un cas (liste vide) donnera un programme qui plante.
#
# **🔴 Expert** — Question ouverte : écris deux pseudo-codes différents pour le même problème (un qui trie d'abord, un qui ne trie pas) — lequel te semble le plus économe ?

# %% [markdown]
# #### ✏️ Activité 1
#
# **🟢 Guidé** — Remets ces 4 lignes de pseudo-code dans le bon ordre pour "compter les nombres pairs d'une liste" :
# ```
#
# a) Je regarde chaque nombre de la liste
# b) Je pars d'un compteur à 0
# c) À la fin, le compteur est la réponse
# d) Si le nombre est pair, j'ajoute 1 au compteur
# ```
#
# **🟡 Intermédiaire** — Écris le pseudo-code puis le code Python de `rechercher_nom(carnet, nom)`.
# *Indice : que se passe-t-il si `carnet` est vide ?*
#
# **🔴 Expert** — Sans pseudo-code fourni : conçois un algorithme qui trouve le minimum ET le maximum d'une liste en un seul parcours.
#
# ---

# %% [markdown]
# ### 📚 Explication 2 — Traduire le pseudo-code en Python
#
# **🎯 Objectif de ce bloc** : traduire fidèlement un pseudo-code en programme Python fonctionnel.
#
# **🟢 Guidé**
# ```python
# liste = [3, 9, 2]
# plus_grand = liste[0]        # étape 1
# for nombre in liste[1:]:     # étape 2
#     if nombre > plus_grand:  # étape 3
#         plus_grand = nombre
# print(plus_grand)            # étape 4
# ```
# Vérification : pourquoi commence-t-on la boucle à `liste[1:]` et pas à `liste[0]` ?
#
# **🟡 Intermédiaire** — Chaque étape du pseudo-code doit correspondre à une ou plusieurs lignes Python, dans le même ordre.
# **Point de vigilance** : toujours dérouler mentalement un cas limite (liste vide, un seul élément) avant de coder.
#
# **🔴 Expert** — Question ouverte : peux-tu écrire une version qui trouve le plus grand nombre EN TRIANT D'ABORD la liste (`sorted(liste)[-1]`) ? Compare avec la version qui parcourt une seule fois.

# %% [markdown]
# #### ✏️ Activité 2
#
# **🟢 Guidé**
# ```python
# liste = [4, 7, 1, 9]
# total = 0
# for x in liste:
#     total = total + ____
# print(total)
# ```
# *Consigne : complète pour calculer la somme de la liste, vérifie que le résultat est 21.*
#
# **🟡 Intermédiaire**
# ```python
# def rechercher_nom(carnet, nom):
#     # traduis ton pseudo-code de l'activité 1 ici
#     pass
#
# carnet = ["Léa", "Tom"]
# print(rechercher_nom(carnet, "Tom"))   # attendu : True
# print(rechercher_nom([], "Léa"))       # attendu : False
# ```
# *Consigne : complète l'implémentation, vérifie les deux résultats attendus.*
#
# **🔴 Expert**
# ```python
# def min_et_max(liste):
#     # à toi d'écrire : renvoie (minimum, maximum) en un seul parcours
#     pass
#
# print(min_et_max([4, 7, 1, 9]))   # attendu : (1, 9)
# ```

# %% [markdown]
# ### 📚 Explication 3 — Comparer deux algorithmes
#
# **🎯 Objectif de ce bloc** : comparer deux pseudo-codes résolvant le même problème et justifier une préférence.
#
# **🟢 Guidé** — Deux pseudo-codes pour "trouver le plus petit nombre" :
# ```
# Version A : parcourir une fois en gardant le plus petit vu
# Version B : trier la liste, puis prendre le premier élément
# ```
# Vérification : laquelle des deux versions regarde chaque nombre une seule fois ?
#
# **🟡 Intermédiaire** — Trier prend plus de temps que de parcourir une seule fois pour un seul besoin ponctuel.
# **Point de vigilance** : si on doit chercher plusieurs fois, la réponse peut changer (voir Séance 5).
#
# **🔴 Expert** — Question ouverte : si la liste a deux fois plus d'éléments, l'algorithme "parcours simple" met-il deux fois plus de temps ? Et l'algorithme "trier puis prendre" ?

# %% [markdown]
# #### ✏️ Activité 3
#
# **🟢 Guidé** — Parmi ces deux bouts de code, lequel parcourt la liste une seule fois ?
# ```python
# # Code 1
# liste_triee = sorted(liste)
# resultat = liste_triee[0]
#
# # Code 2
# resultat = liste[0]
# for x in liste:
#     if x < resultat:
#         resultat = x
# ```
# *Consigne : entoure ta réponse et justifie en une phrase.*
#
# **🟡 Intermédiaire** — Écris les deux versions (parcours simple / tri puis lecture) pour trouver le plus petit nombre d'une liste de notes, et vérifie qu'elles donnent le même résultat.
#
# **🔴 Expert** — Écris un pseudo-code puis un code Python qui trouve "le nom qui apparaît le plus souvent" dans une liste, sans modèle fourni, puis justifie ton choix de structure de données (liste ou dictionnaire).
#
# ### ✅ Bilan de la notion
# - On écrit toujours le pseudo-code avant le code Python, pour vérifier la logique indépendamment de la syntaxe.
# - Chaque étape du pseudo-code doit se retrouver dans le code Python, dans le même ordre.
# - Un cas limite (liste vide, élément unique) doit être envisagé dès le pseudo-code, pas découvert après coup.
# - Plusieurs algorithmes peuvent résoudre le même problème avec des coûts différents — ce choix sera formalisé en Terminale.

# %% [markdown]
# ## 📗 TD
#
# ### Rappel express
# - Toujours écrire le pseudo-code avant le code Python.
# - Chaque étape du pseudo-code correspond à une ou plusieurs lignes Python.
# - Penser aux cas limites (liste vide) dès la conception.
#
# ### 🟢 Partie guidée
# Écris le pseudo-code puis le code Python calculant la somme des éléments de la liste `[4, 7, 1, 9]` (réutilise le modèle de l'Activité 2).
#
# ### 🟡 Partie intermédiaire
# Écris le pseudo-code puis le code Python calculant la moyenne d'une liste de notes, en gérant le cas d'une liste vide (afficher un message adapté plutôt que planter).
#
# ### 🔴 Partie experte
# Compare deux pseudo-codes fournis résolvant tous deux "trouver le plus grand nombre d'une liste" (l'un parcourt une seule fois, l'autre trie d'abord) et explique en une phrase la différence de coût entre les deux.

# %% [markdown]
# ## ✏️ Exercices différenciés finaux
#
# ### 🟢 Exercices Guidés
# 1. Complète le pseudo-code à trous pour calculer la somme des éléments d'une liste, puis traduis-le en Python.
# 2. Remets dans le bon ordre ces 4 étapes de pseudo-code pour compter le nombre de nombres pairs dans une liste.
# 3. QCM : parmi ces 3 pseudo-codes, lequel correspond bien à l'énoncé "afficher le plus petit nombre d'une liste" ?
#
# ### 🟡 Exercices Intermédiaires
# 1. Écris le pseudo-code puis le programme Python qui recherche si un nom donné est présent dans un carnet d'adresses (liste de noms).
# 2. Écris le pseudo-code puis le programme Python qui calcule la moyenne d'une liste de notes, en gérant le cas d'une liste vide.
# 3. Compare deux pseudo-codes fournis résolvant le même problème et explique en une phrase la différence entre les deux.
#
# ### 🔴 Exercices Experts
# 1. Sans pseudo-code fourni : conçois et code un algorithme qui trouve à la fois le minimum ET le maximum d'une liste en un seul parcours.
# 2. Écris deux versions différentes d'un algorithme de recherche dans une liste (avec arrêt anticipé dès que trouvé / sans arrêt anticipé) et explique dans quel cas l'une est préférable à l'autre.
# 3. Défi création : à partir de l'énoncé "trouver le nom qui apparaît le plus souvent dans une liste", conçois ton propre algorithme (pseudo-code + code) sans modèle fourni, puis justifie ton choix de structure de données.
#
# ### 🟣 Défi (pour les élèves en avance)
# Résous "le nom le plus fréquent dans une liste" avec un dictionnaire plutôt qu'avec des listes imbriquées, et compare la lisibilité des deux versions.
#
# ### ✅ Critères de réussite
# - 🟢 Je suis capable de compléter un pseudo-code à trous cohérent et de le traduire en Python.
# - 🟡 Je maîtrise l'écriture d'un pseudo-code complet gérant un cas limite et sa traduction fidèle en Python.
# - 🔴 Je suis capable de concevoir un algorithme original sans modèle et de comparer plusieurs stratégies.
# - 🟣 Je suis capable de résoudre un problème avec une structure de données plus adaptée et de justifier ce choix.
