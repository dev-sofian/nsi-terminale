# %% [markdown]
# # 📘 Cours — Lecture et commentaire de code Python (complexité croissante)
#
# ## Objectif d'apprentissage commun
# > Lire un programme Python de complexité croissante, prédire son comportement, identifier les syntaxes inconnues et les expliquer, et commenter le code pour le rendre compréhensible.

# %% [markdown]
# ## Compétences du programme visées
# - [Préambule commun] « traduire un algorithme dans un langage de programmation, en spécifier les interfaces et les interactions, comprendre et réutiliser des codes sources existants, développer des processus de mise au point et de validation de programmes »
# - [Langages et programmation, BO Terminale — Paradigmes de programmation] « Distinguer sur des exemples les paradigmes impératif, fonctionnel et objet. »
# - [Langages et programmation, BO Première — Diversité et unité des langages] « Repérer, dans un nouveau langage de programmation, les traits communs et les traits particuliers à ce langage. »

# %% [markdown]
# ## 📚 Explication 1 — Lire du code avec des structures déjà connues
#
# ### 🎯 Objectif de ce bloc
# > Prédire la sortie d'un programme utilisant des structures déjà vues (variables, boucles, conditions, fonctions), et le commenter en expliquant l'intention, pas juste la syntaxe.
#
# Lire du code, ce n'est pas l'exécuter mentalement instruction par instruction sans réfléchir : c'est d'abord repérer la **structure générale** (une boucle ? une condition ? une fonction ?), puis **prédire** ce qu'elle produit, avant de vérifier.
#
# ```python
# def traiter(liste):
#     resultat = []
#     for x in liste:
#         if x % 2 == 0:
#             resultat.append(x * 2)
#     return resultat
#
# print(traiter([1, 2, 3, 4, 5]))
# ```

# %% [markdown]
# Commenter ce code ne veut pas dire réécrire chaque ligne en français (`resultat.append(x * 2)  # on ajoute x*2 à resultat`), mais expliquer **l'intention** :
#
# ```python
# def traiter(liste):
#     resultat = []
#     for x in liste:
#         if x % 2 == 0:          # on ne garde que les nombres pairs
#             resultat.append(x * 2)   # qu'on double
#     return resultat   # renvoie les pairs doublés de la liste d'origine
# ```
#
# Vérification : avant d'exécuter, que va afficher `print(traiter([1, 2, 3, 4, 5]))` ?
#
# - [4, 8]

# %% [markdown]
# ## ✏️ Activité 1 — Lire et commenter du code connu
#
# #### 🟢 Guidé
# ```python
# total = 0
# for i in range(1, 6):
#     if i % 2 != 0:
#         total += i
# print(total)
# ```
# ***
# **Consigne :**
#  prédis la sortie sur papier avant d'exécuter. Puis commente chaque ligne en expliquant l'intention (pas la syntaxe).*

# %% [markdown]
# #### 🟡 Intermédiaire
# ```python
# def filtrer_et_transformer(liste, seuil):
#     resultat = []
#     for x in liste:
#         if x >= seuil:
#             resultat.append(x - seuil)
#     return resultat
#
# print(filtrer_et_transformer([5, 12, 3, 20, 8], 10))
# ```
# ***
# **Consigne :**
#  prédis la sortie, puis explique en une phrase ce que fait globalement cette fonction (pas ligne par ligne — le principe général).*

# %% [markdown]
# #### 🔴 Expert
# ```python
# def appliquer_a_tous(liste, fonction):
#     resultat = []
#     for x in liste:
#         resultat.append(fonction(x))
#     return resultat
#
# def doubler(n):
#     return n * 2
#
# print(appliquer_a_tous([1, 2, 3], doubler))
# ```
# ***
# **Consigne :**
#  ce code utilise une fonction (`doubler`) comme argument d'une autre fonction (`appliquer_a_tous`). Explique ce que cela permet de faire que tu ne pourrais pas faire aussi simplement autrement, et prédis la sortie avant d'exécuter.*

# %% [markdown]
# ## 📚 Explication 2 — Lire des syntaxes concises
#
# ### 🎯 Objectif de ce bloc
# > Identifier et comprendre des syntaxes Python plus compactes qui font la même chose que des constructions connues : compréhensions de liste, f-strings, `enumerate`, `zip`.
#
# Certaines écritures Python sont plus **denses** que les constructions de base, mais font exactement la même chose. Il ne s'agit pas d'une logique nouvelle, juste d'une autre façon de l'écrire.
# Testez les codes suivants dans une cellule.

# %% [markdown]
# #### Compréhension.
# Déja vu et revu !
# ```python
# # Version "classique" (déjà connue)
# resultat = []
# for x in [1, 2, 3, 4, 5]:
#     if x % 2 == 0:
#         resultat.append(x * 2)
#
# # Version compacte : compréhension de liste
# resultat = [x * 2 for x in [1, 2, 3, 4, 5] if x % 2 == 0]
# ```
# **Point de vigilance** : face à une compréhension de liste inconnue, la stratégie est de la **réécrire mentalement en boucle classique** pour vérifier qu'on l'a comprise, avant de continuer la lecture.
#
# Vérification : que fait `[n for n in range(10) if n % 3 == 0]` ? Essaie de le dire avant de l'exécuter.

# %% [markdown]
# #### f strings
#
# ```python
# nom, age = "Léa", 17
# print(f"{nom} a {age} ans")            # f-string : insère des variables dans un texte
#
#
# ```

# %% [markdown]
# #### enumerate
# enumerate : donne l'index ET la valeur
# ```python
#
#
# for i, valeur in enumerate(["a", "b", "c"]):
#     print(i, valeur) # enumerate : donne l'index ET la valeur
# ```

# %% [markdown]
# #### zip
# **zip** : parcourt deux listes en parallèle
#
# ```python
#
#
# noms = ["Léa", "Tom"]
# notes = [15, 8]
# for nom, note in zip(noms, notes):
#     print(nom, note)                    # zip : parcourt deux listes en parallèle
# ```

# %% [markdown]
# ## ✏️ Activité 2 — Lire des syntaxes concises
#
# #### 🟢 Guidé
# ```python
# notes = [8, 15, 12, 6, 18]
# admis = [f"Note {n} : validée" for n in notes if n >= 10]
# for ligne in admis:
#     print(ligne)
# ```
#
# **Consigne :**
#  prédis combien de lignes vont s'afficher, puis exécute pour vérifier. Réécris la compréhension `admis = [...]` en boucle `for` classique avec un `.append()`.*

# %% [markdown]
# #### 🟡 Intermédiaire
# ```python
# noms = ["Léa", "Tom", "Zoé"]
# notes = [15, 8, 12]
# for i, (nom, note) in enumerate(zip(noms, notes)):
#     print(i, nom, note)
# ```
#
# **Consigne :**
#  explique ce que fait `zip(noms, notes)` seul, puis ce qu'ajoute `enumerate(...)` autour. Prédis la sortie exacte avant d'exécuter.*

# %% [markdown]
# #### 🔴 Expert
# ```python
# eleves = [("Léa", 15), ("Tom", 8), ("Zoé", 12)]
# resume = [f"{nom} : {'admis' if note >= 10 else 'ajourné'}" for nom, note in eleves]
# print(resume)
# def admission(n):
#     for i, eleve in enumerate(eleves):
#         if i == n:
#             if eleve[1] >= 10:
#                 yield f"{eleve[0]} : admis"
#             else:
#                 yield f"{eleve[0]} : ajourné"
#
# for valeur in admission(len(eleves)):
#     print(valeur)
#
#
# ```
#
# **Consigne :**
#
# ce code combine une compréhension de liste, un unpacking de tuple (`nom, note`) et une expression conditionnelle ternaire (`'admis' if ... else ...`). Décompose-le en 3 étapes séparées avec des boucles classiques, puis vérifie que le résultat final est identique.*

# %% [markdown]
# ## 📚 Explication 3 — Lire des syntaxes avancées
#
# ### 🎯 Objectif de ce bloc
# > Identifier une syntaxe Python inconnue (lambda, map/filter, générateurs), en chercher le sens, et l'expliquer avec ses propres mots.
#
# Certaines syntaxes sont plus rares mais se rencontrent dans du code réel. Face à une syntaxe totalement inconnue, la méthode est :
# -  1) isoler le fragment,
# - 2) le tester seul dans l'interpréteur,
# - 3) reformuler avec ses propres mots.

# %% [markdown]
# Le mot-clé lambda en Python fournit un raccourci pour déclarer de petites fonctions anonymes. Les fonctions lambda se comportent comme des fonctions normales déclarées avec le mot-clé def. Elles peuvent être utilisées chaque fois que des objets de type fonction sont requis.
# Par exemple, voici comment vous définiriez une fonction lambda simple effectuant une addition :
#
# ```python
# addition = lambda x, y: x + y
#  addition(5, 3)
# #8
# ```
# Vous pouvez déclarer la même fonction addition avec le mot-clé def :
# ```python
# def addition(x, y):
#     return x + y
# addition(5, 3)
# #8
# ```

# %% [markdown]
# ```python
# nombres = [1, 2, 3, 4]
# doubles = list(map(lambda x: x * 2, nombres))   # applique lambda à chaque élément
# print(doubles)                     # [2, 4, 6, 8]
# ```

# %% [markdown]
# Un **générateur** ressemble à une fonction, mais utilise `yield` au lieu de `return` : il produit ses valeurs **une par une**, à la demande, plutôt que de toutes les calculer d'un coup.
# ```python
# def compteur(n):
#     for i in range(n):
#         yield i
#
# for valeur in compteur(3):
#     print(valeur)   # affiche 0, puis 1, puis 2
# ```
#
# **Point de vigilance** : `map`, `filter` et les générateurs ne renvoient pas directement une liste — il faut souvent les envelopper dans `list(...)` pour voir leur contenu d'un coup, ou les parcourir avec une boucle `for`.
#
# Vérification : pourquoi `print(compteur(3))` n'affiche-t-il pas `0 1 2`, mais quelque chose comme `<generator object ...>` ?

# %% [markdown]
# ## ✏️ Activité 3 — Lire des syntaxes avancées

# %% [markdown]
# [Map Reduce and Filter Operations in Python](https://www.geeksforgeeks.org/python/map-reduce-and-filter-operations-in-python/)
# [yield](https://www.docstring.fr/glossaire/yield/)

# %% [markdown]
# #### 🟢 Guidé
# ```python
# carre = lambda x: x ** 2
# print(carre(5))
# print(carre(-3))
# ```
# ***
# **Consigne :**
#  réécris `carre` comme une fonction classique avec `def`, en vérifiant qu'elle donne les mêmes résultats.*
#
# #### 🟡 Intermédiaire
# ```python
# nombres = [3, 8, 12, 5, 20, 7]
# pairs = list(filter(lambda x: x % 2 == 0, nombres))
# print(pairs)
# ```
# ***
# **Consigne :**
#  prédis la sortie, puis réécris ce code sans `lambda` ni `filter` (avec une fonction classique nommée et une boucle `for`).*
#
# #### 🔴 Expert
# ```python
# def carres_jusqua(n):
#     for i in range(n):
#         yield i ** 2
#
# generateur = carres_jusqua(5)
# for valeur in generateur:
#     print(valeur)
# ```
# ***
# **Consigne :**
#  explique ligne par ligne ce que fait ce générateur, prédis la sortie de la boucle, puis réécris une version qui fait la même chose mais avec `return` d'une liste complète plutôt que `yield`. Quelle différence de fonctionnement (pas de résultat final) y a-t-il entre les deux versions ?*

# %% [markdown]
# ## ✅ Bilan de la notion
# - Lire du code, c'est d'abord repérer sa structure et **prédire** son comportement avant de l'exécuter.
# - Commenter un code doit expliquer l'**intention**, pas reformuler la syntaxe ligne par ligne.
# - Une syntaxe concise (compréhension, f-string, `enumerate`, `zip`) fait souvent la même chose qu'une construction connue, en plus compact — la réécrire en version classique permet de vérifier qu'on l'a comprise.
# - Face à une syntaxe inconnue (`lambda`, `map`/`filter`, générateurs), la méthode est d'isoler le fragment, de le tester séparément, puis de le reformuler avec ses propres mots.

# %% [markdown]
# ## 📗 TD
#
# ### Rappel express
# - Prédire avant d'exécuter.
# - Commenter = expliquer l'intention, pas la syntaxe.
# - Une syntaxe concise inconnue se comprend en la réécrivant en boucle classique.

# %% [markdown]
# ### 🟢 Partie guidée
# ```python
# def compter_voyelles(mot):
#     total = 0
#     for lettre in mot:
#         if lettre in "aeiouAEIOU":
#             total += 1
#     return total
#
# print(compter_voyelles("Terminale"))
# ```
# ***
# **Consigne :**
#  prédis la sortie, puis commente le code en expliquant l'intention de chaque ligne.*
#
# ### 🟡 Partie intermédiaire
# ```python
# mots = ["chat", "elephant", "abeille", "ours"]
# longs = [f"{m} ({len(m)} lettres)" for m in mots if len(m) > 4]
# for i, ligne in enumerate(longs, start=1):
#     print(i, ligne)
# ```
# ***
# **Consigne :**
#  prédis la sortie exacte (attention à `start=1` dans `enumerate`), puis réécris ce code entièrement avec des boucles `for` classiques.*
#
# ### 🔴 Partie experte
# ```python
# operations = {
#     "addition": lambda a, b: a + b,
#     "soustraction": lambda a, b: a - b,
#     "multiplication": lambda a, b: a * b
# }
#
# for nom, fonction in operations.items():
#     print(nom, fonction(6, 3))
# ```
# ***
# **Consigne :**
#  explique ce que fait ce dictionnaire dont les valeurs sont des fonctions `lambda`. Prédis la sortie, puis réécris ce code sans dictionnaire ni `lambda`, en utilisant des fonctions classiques et une suite de `if`/`elif`.*

# %% [markdown]
# ## ✏️ Exercices différenciés — Lecture et commentaire de code (version complète)
#
# ### 🟢 Exercices Guidés
#
# **1. Prédis la sortie, puis vérifie**
# ```python
# total = 0
# for i in range(1, 8):
#     if i % 3 == 0:
#         total = total + i
# print(total)
# ```
# *Consigne : sur papier, prédis ce que va afficher `print(total)` avant d'exécuter. Vérifie ensuite.*
#
# **2. Commente ce code en expliquant l'intention (pas la syntaxe)**
# ```python
# def nettoyer(mots):
#     resultat = []
#     for mot in mots:
#         if len(mot) > 3:
#             resultat.append(mot.lower())
#     return resultat
# ```
# *Consigne : ajoute un commentaire à côté de chaque ligne, qui explique CE QUE la ligne accomplit dans le programme (pas ce qu'elle fait techniquement). Exemple à éviter : `resultat.append(...)  # on ajoute à resultat`.*
#
# **3. Repère l'erreur d'indentation sans exécuter**
# ```python
# def calculer_moyenne(notes):
#     total = 0
#     for n in notes:
#     total = total + n
#         moyenne = total / len(notes)
#     return moyenne
# ```
# *Consigne : identifie la ou les lignes mal indentées, explique pourquoi c'est un problème, puis corrige le code.*
#
# ---
#
# ### 🟡 Exercices Intermédiaires
#
# **1. Prédis la sortie d'une compréhension, puis réécris-la en boucle classique**
# ```python
# mots = ["chat", "elephant", "abeille", "ours", "cheval"]
# resultat = [mot.upper() for mot in mots if len(mot) <= 5]
# print(resultat)
# ```
# *Consigne : prédis la sortie exacte (ordre et contenu), vérifie, puis réécris `resultat = [...]` avec une boucle `for` classique et `.append()`.*
#
# **2. Explique `zip` et `enumerate` combinés**
# ```python
# villes = ["Paris", "Lyon", "Marseille"]
# populations = [2148000, 513000, 870000]
#
# for i, (ville, pop) in enumerate(zip(villes, populations), start=1):
#     print(f"{i}. {ville} : {pop} habitants")
# ```
# *Consigne : explique séparément ce que fait `zip(villes, populations)`, puis ce qu'ajoute `enumerate(..., start=1)`. Prédis la sortie ligne par ligne avant d'exécuter.*
#
# **3. Réécris une expression ternaire avec un `if`/`else` classique**
# ```python
# notes = [8, 15, 6, 12, 17, 9]
# resultats = ["admis" if n >= 10 else "ajourné" for n in notes]
# print(resultats)
# ```
# *Consigne : prédis la sortie, puis réécris tout le programme (compréhension + ternaire) avec une boucle `for` classique et un `if`/`else` explicite.*
#
# ---
#
# ### 🔴 Exercices Experts
#
# **1. Réécris `lambda` + `filter` avec une fonction classique et une boucle**
# ```python
# temperatures = [12, -3, 25, 0, -8, 18, 30]
# gelives = list(filter(lambda t: t < 0, temperatures))
# print(gelives)
# ```
# *Consigne : prédis la sortie, puis réécris ce code sans `lambda` ni `filter` : définis une fonction `est_negatif(t)` avec `def`, et utilise une boucle `for` avec un `.append()` pour construire `gelives`.*
#
# **2. Explique un générateur face à une fonction classique**
# ```python
# def multiples_de(n, limite):
#     for i in range(1, limite + 1):
#         if i % n == 0:
#             yield i
#
# for valeur in multiples_de(3, 15):
#     print(valeur)
# ```
# *Consigne : explique ligne par ligne ce que fait ce générateur, prédis la sortie de la boucle qui l'utilise. Écris ensuite une version `multiples_de_liste(n, limite)` qui fait la même chose mais avec `return` d'une liste complète plutôt que `yield`. Quelle différence de fonctionnement (pas de résultat final affiché) y a-t-il entre les deux si on ne fait qu'appeler la fonction sans la parcourir ?*
#
# **3. Décompose et réécris un code combinant plusieurs syntaxes avancées**
# ```python
# eleves = [("Léa", [15, 12, 18]), ("Tom", [8, 6, 9]), ("Zoé", [17, 14, 16])]
#
# moyennes = {nom: sum(notes) / len(notes) for nom, notes in eleves}
# classement = sorted(moyennes.items(), key=lambda item: item[1], reverse=True)
#
# for nom, moyenne in classement:
#     print(f"{nom} : {moyenne:.1f}")
# ```
# *Consigne : ce code combine une compréhension de dictionnaire, un unpacking de tuples, un tri avec `lambda` comme clé, et un f-string avec formatage (`:.1f`). Décompose-le en au moins 4 étapes séparées avec des boucles et variables classiques, en gardant le même résultat final. Explique en particulier ce que fait `key=lambda item: item[1]` dans le tri.*
#
# ---
#
# ## ✅ Critères de réussite (rappel)
# - 🟢 Je suis capable de prédire la sortie d'un code utilisant des structures connues et de le commenter en expliquant l'intention.
# - 🟡 Je maîtrise la lecture de syntaxes concises (compréhensions, f-strings, `enumerate`, `zip`, expression ternaire) et je peux les réécrire en version classique.
# - 🔴 Je suis capable de lire et transformer du code utilisant `lambda`, `map`/`filter` et des générateurs, et de décomposer un code combinant plusieurs syntaxes avancées.

# %% [markdown]
# ## ✅ Critères de réussite
# - 🟢 Je suis capable de prédire la sortie d'un code utilisant des structures connues et de le commenter en expliquant l'intention.
# - 🟡 Je maîtrise la lecture de syntaxes concises (compréhensions, f-strings, `enumerate`, `zip`) et je peux les réécrire en version classique.
# - 🔴 Je suis capable de lire et transformer du code utilisant `lambda`, `map`/`filter` et des générateurs.
# - 🟣 Je suis capable d'appliquer la méthode de lecture à un code réel non préparé pour l'exercice.
